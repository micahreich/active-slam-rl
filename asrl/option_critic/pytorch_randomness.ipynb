# %%
import torch
import numpy as np

# %%
layer = torch.nn.Linear(3, 10)

x = torch.randn(3)
out = layer(x)
out_argmax = out.argmax(dim=-1)

print("x:", x)
print("out:", out)
print("out_argmax:", out_argmax.item())
# Out:
# x: tensor([0.9391, 0.1523, 0.1500])
# out: tensor([-0.3825, -0.3302,  0.2633, -0.0341,  0.1898,  0.4343,  0.4234,  0.2576,
#          0.0054, -0.6990], grad_fn=<ViewBackward0>)
# out_argmax: 5
