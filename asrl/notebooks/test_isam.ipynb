# %%
import gtsam
import numpy as np
import matplotlib.pyplot as plt

# %%
params = gtsam.ISAM2Params()
params.setRelinearizeThreshold(0.01)
isam = gtsam.ISAM2(params)

# A graph & set of new estimates that we’ll feed to iSAM2 incrementally
new_factors = gtsam.NonlinearFactorGraph()
new_values  = gtsam.Values()

linear_graph = isam.getFactorsUnsafe().linearize(isam.calculateEstimate())

# %%
linear_graph
# Out:
# size: 0
