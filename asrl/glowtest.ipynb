# %%
# Import required packages
import torch
from torch import nn
from torch.distributions import Uniform
import numpy as np
import normflows as nf

from matplotlib import pyplot as plt

from tqdm import tqdm

# %%
d = 10
b = torch.Tensor([1 if i % 2 == 0 else 0 for i in range(d)])
b = b.repeat(3, 1)

xs = torch.randn(32, 3, d)
ys = b * xs

print(ys[0])
# Out:
# tensor([[ 0.7845,  0.0000,  0.6086, -0.0000, -0.4116, -0.0000,  0.0544,  0.0000,
#          -0.8038, -0.0000],
#         [ 0.6582, -0.0000, -0.1006,  0.0000, -0.8224,  0.0000,  1.3099,  0.0000,
#          -1.5400,  0.0000],
#         [-0.0960, -0.0000, -0.3841,  0.0000, -1.4431, -0.0000, -0.9220, -0.0000,
#          -2.1271, -0.0000]])
